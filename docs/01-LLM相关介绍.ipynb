# %% [markdown]
# ## 介绍
# 大模型指的是理解和生成人类语言的模型
#
# ## 特点
# 1. 上下文感知。大模型能够理解和生成依赖于前文的内容，用于当前文档的生成。
#
# 2. 多模态的支持。
#
# 3. 多语言的支持。
#
# ## 能力
#
# 1. 上下文理解
#
# 2. 指令遵从。大模型能够自然语言描述，完成任务。
#
# 3. 逐步推理。现在的模型基本都满足COT chain of thought的能力。可以通过中间步骤的推理，一步一步的完成任务。
